# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.ticker import MultipleLocator, LogLocator

# %% [markdown]
# ### create data frame

# %%
url='https://github.com/babayChris/physics77Capstone/raw/refs/heads/main/data/6%20class%20csv.csv'
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
temp='Temperature (K)'
L='Luminosity(L/Lo)'
r='Radius(R/Ro)'
abs_mag='Absolute magnitude(Mv)'
st='Star type'
sc='Star color'
spec='Spectral Class'

# %% [markdown]
# ### H-R Diagram

# %%
sns.scatterplot(data=df,x=temp,y=abs_mag,hue=st,palette='Spectral')
sns.set(rc={'axes.facecolor':'black'})
#plt.yscale('log')
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.xscale('log')
plt.title('H-R Diagram')
legend = plt.legend()
frame = legend.get_frame()
frame.set_facecolor('white')
plt.xticks([50000,30000, 10000,3000, 1000], ['50000','30000', '10000','3000', '1000'])
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### I. correlation map

# %%
sns.pairplot(df.iloc[:,:-3].corr(),height=2, aspect=1.2)#without star type, star color, and spectral class
plt.show()

# %%
sns.heatmap(df.iloc[:,:-3].corr(),annot=True)
plt.show()

# %% [markdown]
# ### II. scatter/box plots

# %%
plt.figure(figsize=(18,8))
plt.subplot(1,3,1)
sns.scatterplot(data=df,x=temp,y=L,hue=st)
plt.subplot(1,3,2)
sns.scatterplot(data=df,x=temp,y=r,hue=st)
plt.subplot(1,3,3)
sns.scatterplot(data=df,x=temp,y=abs_mag,hue=st)
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.subplot(1,3,1)
sns.boxplot(data=df, x=st, y=abs_mag)
plt.subplot(1,3,2)
sns.boxplot(data=df, x=st, y=temp)
plt.yscale('log')
plt.subplot(1,3,3)
sns.boxplot(data=df, x=st, y=L)
plt.yscale('log')

plt.show()

# %%
plt.figure(figsize=(18,8))
plt.subplot(1,3,1)
sns.boxplot(data=df, x=spec, y=abs_mag)
plt.subplot(1,3,2)
sns.boxplot(data=df, x=spec, y=temp) ## particularly useful, others don't show much
plt.yscale('log')
plt.subplot(1,3,3)
sns.boxplot(data=df, x=spec, y=L)
plt.yscale('log')
